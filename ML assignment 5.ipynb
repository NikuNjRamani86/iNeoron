# %% [markdown]
# #### 1. What are the key tasks that machine learning entails? What does data pre-processing imply?
# - it is type of inference or prediction being made, based on the problem statement is asked and availability of the data.
# - suppose, regression task assigns data to prediction something, in the classification task assigns data to categories, and clustering task groups data according to similarity
# - Data preprocessing is the process of transforming raw data into an understandable format because of machine learning not understand raw data.

# %% [markdown]
# #### 2. Describe quantitative and qualitative data in depth. Make a distinction between the two.
# - Quantitative data
#  - Data that can be numerically analyzed and quantified into hard facts.
#  - Data can be measured and expressed numerically
#  - It is number-based
#  - Statistical analysis is easier
#  - Sample size is large
#  - Data collected using surveys, observatons, exprements
#  - For example, nikunj has size 6 feet and 60kg weights
# - Qualitative data
#  - Non-numerical data that describes qualities, opinions, or feelings
#  - Data type that consists of descriptive statements
#  - It is text-based
#  - Statistical analysis is harder
#  - Sample size is small
#  - Data collected using interviews, written documents, observations
#  - For example, Nikunj has blue eyes and he has curly hair

# %% [markdown]
# #### 3. Create a basic data collection that includes some sample records. Have at least one attribute from each of the machine learning data types.
# - Mainly four basic types of data used in machine learning: Numerical data, Categorical data, Time-series data and Text data
#
# 1) Determine which types of information you want to collect.
# 2) Set a timeframe for data collection
# 3) Find which method you choose for data collection
# 4) Collect the data
# 5) Analyze the data and implement your finding
#
# - Numerical data - Data collected using surveys, observatons, exprements
# - Categorical data - Data collected using interviews, written documents, observations
# - Time series - It can be weather forecasting, stock-price prediction

# %% [markdown]
# #### 4. What are the various causes of machine learning data issues? What are the ramifications?
# - Issues
#  - poor quality of data
#  - overfitting and underfitting problem
#  - inadequate training data
#  - non-representative training data
#  - lack sklilled resources
#  - customer segmentation
#
# - Ramifications
#  - reduce the model performance
#  - model give bad accuracy
#  - model will not generalize
#  - overfitting and underfitting problem happen

# %% [markdown]
# #### Demonstrate various approaches to categorical data exploration with appropriate examples.
# - Mode - most frequently occurring value in the given data
#  - for example data=['nik','nik','nikunj','nik']
#  - Mode = 'nik'
# - Bar charts - Frequency of each category plotted as bars.
# - ![image.png](attachment:image.png)
# - Pie charts - Frequency of each category plotted as pie or wedges. It is a circular graph, where the arc length of each slice is proportional to the quantity it represents.
# - ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 6. How would the learning activity be affected if certain variables have missing values? Having said that, what can be done about it?
# - Missing data is reduce statistical power, which refers to the probability that the test will reject the null hypothesis when it is false.
# - The lost data can cause bias in the estimation of parameters.
# - It can reduce the representativeness of the samples
#
# - so that, we need to remove or imputation data in place of missing data

# %% [markdown]
# #### 7. Describe the various methods for dealing with missing data values in depth.
# - Mean/median/mode imputation: you can replace mean/mode/median of the data in palce of missing value.
# - Random sample imputation: You can replace random data in place of missing data.
# - End of distribution: you can replace outliers in place of missing data.
# - Replace with previous value
# - Replace with next value
# - Arbitrary value imputation: it consists of replacing Nan by an arbitary value.

# %% [markdown]
# #### 8. What are the various data pre-processing techniques? Explain dimensionality reduction and function selection in a few words.
# - Handle the missing data
# - Handle noisy data
# - handle the outliers
# - normalization
# - smoothing
# - dimensionality reduction
# ---
# - Dimesionality reduction is transform features into a lower dimension. suppose 1000 features in the dataset, we convert 1000 to 100 features and that 100 represent the 1000 features data.
# - Feature selection is simply selecting and excluding given features without changing them. suppose 100 features in the dataset. but 10 features are highly affected target variables so that consider only that 10 features

# %% [markdown]
# #### 9.i. What is the IQR? What criteria are used to assess it?
# - Inter Quartile Range. it is subtract the first quartile from the third quartile(Q3-Q1)
# - it is used to measure how spread out the data points in a set are form the mean of the data set.
# - High IQR means more spread out the data from the mean
# - Low IQR menas data bunched up the data points are around the mean
#
# #### ii. Describe the various components of a box plot in detail? When will the lower whisker surpass the upper whisker in length? How can box plots be used to identify outliers?
# - ![image.png](attachment:image.png)
# - min - minimun value in the dataset
# - lower quartile(Q1) - first quartile of the data
# - Median - Mid data in the dataset
# - upper quartile(Q3) - third quartile of the data
# - max - maximum value in the dataset
# ---
# - the length of the lower whisker is the largest value that is greater than the third quartilr + 1.5*IQR
# ---
# - lower limit = Q1-1.5*IQR
# - upper limit = Q3+1.5*IQR
# - Outliers data are below the lower limit and above the upper limit

# %% [markdown]
# #### 10. Make brief notes on any two of the following:
# #### The gap between the quartiles
# - the gap between the quartiles is called IQR
# - IQR find with help of first quartile and third quartile
# - IQR is nothing but it is difference between q1 and q3
# - if gap is more that means data spread more around the mean and less gap indicate most of the data fall near to mean of the data
#
# #### Cross tab
# - a cross tab is a table showing the relationship between two or more variables.
# - it is also called contingency table
# - here, table show only the relationship between two cztegorical variables

# %% [markdown]
# #### 2. Make a comparison between:
# #### Histogram and box plot
# - Histogram:
#  - it is type of bar chart
#  - it display the frequancies of a dataset
#  - it is highly useful whenwide variances axist among the observed frequencies for a particular data set.
#  - ![image.png](attachment:image.png)
#
# - Box plot
#  - it is also called box-and-whisker plot
#  - it represent the five most important descriptive values for a data set.
#  - minimum, first quartile, median, third quartile, maximum.
#  -

# %% [markdown]
# #### The average and median
# - Average:
#  - it is calculated by adding up all of the value and dividing this total by the number of observation
#  - it is also called mean
#
# - Median:
#  - it is middle number in the set of data.
#  - first the order from the ascending or decending order and find middle number
